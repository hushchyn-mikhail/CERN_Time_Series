# %% [markdown]
# #Introduction

# %% [markdown]
# This notebook is a review of the Data Popularity Project. All notebooks are located here:
# [Data Popularity](http://nbviewer.ipython.org/github/hushchyn-mikhail/CERN_Time_Series/tree/master/)
#
# The project has a book-like structure.
# All notebooks for the same approach of an analysis are located in the same chapter. For example, all notebooks for time series analysis are located in chapter A.
#
# The image below gives intuition of the notebooks order:
# ![Notebooks order](https://raw.githubusercontent.com/hushchyn-mikhail/CERN_Time_Series/master/images/TimeLine.png)

# %% [markdown]
# #Data

# %% [markdown]
# Data for the project is here: [Data](https://github.com/hushchyn-mikhail/CERN_Time_Series/blob/master/popularity-728days_my.xls)
#
# Note, that data was modified. Week numbers were renumbered as follow:
# ![Week numbers](https://raw.githubusercontent.com/hushchyn-mikhail/CERN_Time_Series/master/images/TimeSeries.png)
#
# Time series examples are here: [Time Series](http://nbviewer.ipython.org/github/hushchyn-mikhail/CERN_Time_Series/blob/master/DatasetsExamples.ipynb)

# %% [markdown]
# #Articles
#
# Several related articles here: [Articles](http://nbviewer.ipython.org/github/hushchyn-mikhail/CERN_Time_Series/blob/master/ArticleNotes/notebook.ipynb)

# %% [markdown]
# #The best results for now:
#
# Notebooks [B3.2.1](http://nbviewer.ipython.org/github/hushchyn-mikhail/CERN_Time_Series/blob/master/B._Classification/B3.2.1._NewFeatures_52weeks/notebook.ipynb) and [B3.2.2](http://nbviewer.ipython.org/github/hushchyn-mikhail/CERN_Time_Series/blob/master/B._Classification/B3.2.2._NewFeatures_78weeks/notebook.ipynb) and all notebooks in [C](http://nbviewer.ipython.org/github/hushchyn-mikhail/CERN_Time_Series/tree/master/C._NewFeatures/) give better results.

# %% [markdown]
# #Description and comparison of all methods:

# %%
# %pylab inline
from cern_utils import calc_util
import ipykee
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# #Chapter A
#
# In this chapter was applied time series analysis approach to the data.
# All notebooks for the chapter here: [Chapter A](http://nbviewer.ipython.org/github/hushchyn-mikhail/CERN_Time_Series/tree/master/A._TimeSeriesAnalysis/)
#
# The chapter contains 2 main sections, A1 and A2.

# %% [markdown]
# ###Section A1

# %% [markdown]
# **A1.1:** In notebooks [A1.1.1](http://nbviewer.ipython.org/github/hushchyn-mikhail/CERN_Time_Series/blob/master/A._TimeSeriesAnalysis/A1.1.1._TSA_ModelOutputs_Cumulative_1-52Weeks.ipynb) and [A1.1.2](http://nbviewer.ipython.org/github/hushchyn-mikhail/CERN_Time_Series/blob/master/A._TimeSeriesAnalysis/A1.1.2._TSA_ModelOutputs_Cumulative_1-78Weeks.ipynb) Holt's model with linear trend was applied to cumulative time series. The results of the model were saved were used in other notebooks in this section.

# %% [markdown]
# **A1.2:** Notebook [A1.2.1](http://nbviewer.ipython.org/github/hushchyn-mikhail/CERN_Time_Series/blob/master/A._TimeSeriesAnalysis/A1.2.1._TSAResults_Cumulative.ipynb) contains the distributions of the variables which were got in A1.1.1 and A1.1.2.
# Also, this notebook contains one of the approaches of the analysis. Because of this approach will not be used in future, this notebook can be skiped.

# %% [markdown]
# **A1.3:** Notebook [A.1.3.1](http://nbviewer.ipython.org/github/hushchyn-mikhail/CERN_Time_Series/blob/master/A._TimeSeriesAnalysis/A1.3.1._TSA_Cumulative_52weeks/notebook.ipynb) shows the approach which will be used in other notebooks. Data for the 1-52 weeks was used as train data in this notebook.

# %%
#get variables
keeper = ipykee.Keeper("A._TimeSeriesAnalysis")
session = keeper["A1.3.1._TSA_Cumulative_52weeks"]
vars_a131 = session.get_variables("master")
#variables.keys()
# Out:
# Please, save your notebook before commit!

# %% [markdown]
# * Notebook [A.1.3.2](http://nbviewer.ipython.org/github/hushchyn-mikhail/CERN_Time_Series/blob/master/A._TimeSeriesAnalysis/A1.3.2._TSA_Cumulative_78weeks/notebook.ipynb) shows the approach which will be used in other notebooks. Data for the 1-78 weeks was used as train data in this notebook.

# %%
#get variables
keeper = ipykee.Keeper("A._TimeSeriesAnalysis")
session = keeper["A1.3.2._TSA_Cumulative_78weeks"]
vars_a132 = session.get_variables("master")
#variables.keys()
# Out:
# Please, save your notebook before commit!

# %% [markdown]
# ###Section A2

# %% [markdown]
# **A2.1:** In notebooks [A2.1.1](http://nbviewer.ipython.org/github/hushchyn-mikhail/CERN_Time_Series/blob/master/A._TimeSeriesAnalysis/A2.1.1._TSA_ModelOutputs_RollingMean_1-52Weeks.ipynb) and [A2.1.2](http://nbviewer.ipython.org/github/hushchyn-mikhail/CERN_Time_Series/blob/master/A._TimeSeriesAnalysis/A2.1.2._TSA_ModelOutputs_RollingMean_1-78Weeks.ipynb) Holt's model with linear trend was applied to time series. Rolling mean with 26-weeks-window values were calculated for the time series. The results of the model were saved were used in other notebooks in this section.

# %% [markdown]
# **A2.2:** Notebook [A2.2.1](http://nbviewer.ipython.org/github/hushchyn-mikhail/CERN_Time_Series/blob/master/A._TimeSeriesAnalysis/A2.2.1._TSAResults_RollingMean.ipynb) contains the distributions of the variables which were got in A2.1.1 and A2.1.2.
# Also, this notebook contains one of the approaches of the analysis. Because of this approach will not be used in future, this notebook can be skiped.

# %% [markdown]
# **A1.3:** Notebook [A.1.3.1](http://nbviewer.ipython.org/github/hushchyn-mikhail/CERN_Time_Series/blob/master/A._TimeSeriesAnalysis/A2.3.1._TSA_RollingMean26_52weeks/notebook.ipynb) shows the approach which will be used in other notebooks. Data for the 1-52 weeks was used as train data in this notebook.

# %%
#get variables
keeper = ipykee.Keeper("A._TimeSeriesAnalysis")
session = keeper["A2.3.1._TSA_RollingMean26_52weeks"]
vars_a231 = session.get_variables("master")
#variables.keys()
# Out:
# Please, save your notebook before commit!

# %% [markdown]
# * Notebook [A.2.3.2](http://nbviewer.ipython.org/github/hushchyn-mikhail/CERN_Time_Series/blob/master/A._TimeSeriesAnalysis/A2.3.2._TSA_RollingMean26_78weeks/notebook.ipynb) shows the approach which will be used in other notebooks. Data for the 1-78 weeks was used as train data in this notebook.

# %%
#get variables
keeper = ipykee.Keeper("A._TimeSeriesAnalysis")
session = keeper["A2.3.2._TSA_RollingMean26_78weeks"]
vars_a232 = session.get_variables("master")
#variables.keys()
# Out:
# Please, save your notebook before commit!

# %% [markdown]
# **Comparison of the models in chapter A**

# %%
#ROC - curve
figure(figsize=(15, 5))
subplot(121)
vars_a131['report.roc()'].plot()
vars_a132['report.roc()'].plot()
vars_a231['report.roc()'].plot()
vars_a232['report.roc()'].plot()
legend(['A1.3.1', 'A1.3.2', 'A2.3.1', 'A2.3.2'], loc='best')
subplot(122)
vars_a131['report2.roc()'].plot()
vars_a132['report2.roc()'].plot()
vars_a231['report2.roc()'].plot()
vars_a232['report2.roc()'].plot()
legend(['A1.3.1', 'A1.3.2', 'A2.3.1', 'A2.3.2'], loc='best')

# %% [markdown]
# ###Results:
# It seems that A1.3.1 notebook gives better results

# %% [markdown]
# #Chapter B

# %% [markdown]
# Features from time series analysis model and given data set's features were used to train a classifier in this chapter.
#
# The chapter contains 3 sections: B1, B2, B3

# %% [markdown]
# ###Section B1

# %% [markdown]
# **B1.1:** In notebook [B1.1.1](http://nbviewer.ipython.org/github/hushchyn-mikhail/CERN_Time_Series/blob/master/B._Classification/B1.1.1._Classifier_Cumulative/notebook.ipynb) features from the [Data](https://github.com/hushchyn-mikhail/CERN_Time_Series/blob/master/popularity-728days_my.xls) were used to train a classifier and predict future popularities of the data sets.
#
# This notebook just shows that this approach is bad for popularity prediction.

# %%
#get variables
keeper = ipykee.Keeper("B._Classification")
session = keeper["B1.1.1._Classifier_Cumulative"]
vars_b111 = session.get_variables("master")
#variables.keys()
# Out:
# Please, save your notebook before commit!

# %% [markdown]
# **B1.2:** In notebook [B1.2.1](http://nbviewer.ipython.org/github/hushchyn-mikhail/CERN_Time_Series/blob/master/B._Classification/B1.2.1._Classifier_and_TSA_Cumulative/notebook.ipynb) results from notebook A1.1.1 and features from the [Data](https://github.com/hushchyn-mikhail/CERN_Time_Series/blob/master/popularity-728days_my.xls) were used to train a classifier and predict future popularities of the data sets.
#
# This notebook just shows that this approach is bad for popularity prediction.

# %%
#get variables
keeper = ipykee.Keeper("B._Classification")
session = keeper["B1.2.1._Classifier_and_TSA_Cumulative"]
vars_b121 = session.get_variables("master")
#variables.keys()
# Out:
# Please, save your notebook before commit!

# %% [markdown]
# * In notebook [B1.2.2](http://nbviewer.ipython.org/github/hushchyn-mikhail/CERN_Time_Series/blob/master/B._Classification/B1.2.2._Classifier_and_TSA_Cumulative_Grouped/notebook.ipynb) results from notebook A1.1.1 and features from the [Data](https://github.com/hushchyn-mikhail/CERN_Time_Series/blob/master/popularity-728days_my.xls) were used to train a classifier and predict future popularities of the data sets. All data sets were grouped in groups.
#
# This notebook just shows that this approach is bad for popularity prediction.

# %%
#get variables
keeper = ipykee.Keeper("B._Classification")
session = keeper["B1.2.2._Classifier_and_TSA_Cumulative_Grouped"]
vars_b122 = session.get_variables("master")
#variables.keys()
# Out:
# Please, save your notebook before commit!

# %% [markdown]
# **B1.3:** In notebooks [B1.3.1](http://nbviewer.ipython.org/github/hushchyn-mikhail/CERN_Time_Series/blob/master/B._Classification/B1.3.1._TSA_Cumulative_52weeks.ipynb) and [B1.3.2](http://nbviewer.ipython.org/github/hushchyn-mikhail/CERN_Time_Series/blob/master/B._Classification/B1.3.2._TSA_Cumulative_78weeks.ipynb) are the same for the **A1.3**.

# %% [markdown]
# **Comparison of the models in section B1**

# %%
#ROC - curve
figure(figsize=(8, 5))
vars_b111['report2.roc()'].plot()
vars_b121['report2.roc()'].plot()
vars_b122['report2.roc()'].plot()
vars_a131['report.roc()'].plot()
vars_a132['report.roc()'].plot()
legend(['B1.1.1','B1.2.1', 'B1.2.2', 'B1.3.1(A1.3.1)', 'B1.3.2(A1.3.2)'], loc='best')

# %% [markdown]
# And again, notebook [A.1.3.1](http://nbviewer.ipython.org/github/hushchyn-mikhail/CERN_Time_Series/blob/master/A._TimeSeriesAnalysis/A2.3.1._TSA_RollingMean26_52weeks/notebook.ipynb) shows better results.

# %% [markdown]
# ###Section B2

# %% [markdown]
# **B2.1:** In notebook [B2.1.1](http://nbviewer.ipython.org/github/hushchyn-mikhail/CERN_Time_Series/blob/master/B._Classification/B2.1.1._Classifier_Rolling_Mean/notebook.ipynb) features from the [Data](https://github.com/hushchyn-mikhail/CERN_Time_Series/blob/master/popularity-728days_my.xls) were used to train a classifier and predict future popularities of the data sets. Rolling mean with 26-weeks-window values were calculated for the time series.
#
# This notebook just shows that this approach is bad for popularity prediction.

# %%
#get variables
keeper = ipykee.Keeper("B._Classification")
session = keeper["B2.1.1._Classifier_Rolling_Mean"]
vars_b211 = session.get_variables("master")
#variables.keys()
# Out:
# Please, save your notebook before commit!

# %% [markdown]
# **B2.2:** In notebook [B2.2.1](http://nbviewer.ipython.org/github/hushchyn-mikhail/CERN_Time_Series/blob/master/B._Classification/B2.2.1._Classifier_and_TSA_RollingMean/notebook.ipynb) results from notebook A2.1.1 and features from the [Data](https://github.com/hushchyn-mikhail/CERN_Time_Series/blob/master/popularity-728days_my.xls) were used to train a classifier and predict future popularities of the data sets. Rolling mean with 26-weeks-window values were calculated for the time series.
#
# This notebook just shows that this approach is bad for popularity prediction.

# %%
#get variables
keeper = ipykee.Keeper("B._Classification")
session = keeper["B2.2.1._Classifier_and_TSA_RollingMean"]
vars_b221 = session.get_variables("master")
#variables.keys()
# Out:
# Please, save your notebook before commit!

# %% [markdown]
# * In notebook [B2.2.2](http://nbviewer.ipython.org/github/hushchyn-mikhail/CERN_Time_Series/blob/master/B._Classification/B2.2.2._Classifier_and_TSA_RollinMean_Grouped/notebook.ipynb) results from notebook A1.1.1 and features from the [Data](https://github.com/hushchyn-mikhail/CERN_Time_Series/blob/master/popularity-728days_my.xls) were used to train a classifier and predict future popularities of the data sets. Rolling mean with 26-weeks-window values were calculated for the time series. All data sets were grouped in groups.
#
# This notebook just shows that this approach is bad for popularity prediction.

# %%
#get variables
keeper = ipykee.Keeper("B._Classification")
session = keeper["B2.2.2._Classifier_and_TSA_RollinMean_Grouped"]
vars_b222 = session.get_variables("master")
#variables.keys()
# Out:
# Please, save your notebook before commit!

# %% [markdown]
# **B2.3:** In notebooks [B2.3.1](http://nbviewer.ipython.org/github/hushchyn-mikhail/CERN_Time_Series/blob/master/B._Classification/B2.3.1._TSA_RollingMean26_52weeks.ipynb) and [B2.3.2](http://nbviewer.ipython.org/github/hushchyn-mikhail/CERN_Time_Series/blob/master/B._Classification/B2.3.2._TSA_RollingMean26_78weeks.ipynb) are the same for the **A2.3**.

# %% [markdown]
# **Comparison of the models in section B2**

# %%
#ROC - curve
figure(figsize=(8, 5))
vars_b211['report2.roc()'].plot()
vars_b221['report2.roc()'].plot()
vars_b222['report2.roc()'].plot()
vars_a231['report.roc()'].plot()
vars_a232['report.roc()'].plot()
legend(['B2.1.1','B2.2.1', 'B2.2.2', 'B2.3.1(A2.3.1)', 'B2.3.2(A2.3.2)'], loc='best')

# %% [markdown]
# And again, notebook [A.2.3.1](http://nbviewer.ipython.org/github/hushchyn-mikhail/CERN_Time_Series/blob/master/A._TimeSeriesAnalysis/A2.3.1._TSA_RollingMean26_52weeks.ipynb) shows better results.

# %% [markdown]
# ###Section B3

# %% [markdown]
# **B3.2:** In notebook [B3.2.1](http://nbviewer.ipython.org/github/hushchyn-mikhail/CERN_Time_Series/blob/master/B._Classification/B3.2.1._NewFeatures_52weeks/notebook.ipynb) new features were created. Data for the 1-52 weeks was used as train data in this notebook.

# %%
#get variables
keeper = ipykee.Keeper("B._Classification")
session = keeper["B3.2.1._NewFeatures_52weeks"]
vars_b321 = session.get_variables("master")
#variables.keys()
# Out:
# Please, save your notebook before commit!

# %% [markdown]
# * In notebook [B3.2.2](http://nbviewer.ipython.org/github/hushchyn-mikhail/CERN_Time_Series/blob/master/B._Classification/B3.2.2._NewFeatures_78weeks/notebook.ipynb) new features were created. Data for the 1-78 weeks was used as train data in this notebook.

# %%
#get variables
keeper = ipykee.Keeper("B._Classification")
session = keeper["B3.2.2._NewFeatures_78weeks"]
vars_b322 = session.get_variables("master")
#variables.keys()
# Out:
# Please, save your notebook before commit!

# %% [markdown]
# **Comparison of the models in chapters B and A**

# %%
#ROC - curve
figure(figsize=(15, 5))
subplot(121)
vars_a131['report.roc()'].plot()
vars_a132['report.roc()'].plot()
vars_a231['report.roc()'].plot()
vars_a232['report.roc()'].plot()
vars_b321['report.roc()'].plot()
vars_b322['report.roc()'].plot()
legend(['A1.3.1(B1.3.1)', 'A1.3.2(B1.3.2)', 'A2.3.1(B2.3.2)', 'A2.3.2(B2.3.2)', 'B3.2.1', 'B3.2.2'], loc='best')
subplot(122)
vars_a131['report2.roc()'].plot()
vars_a132['report2.roc()'].plot()
vars_a231['report2.roc()'].plot()
vars_a232['report2.roc()'].plot()
vars_b321['report.roc()'].plot()
vars_b322['report2.roc()'].plot()
legend(['A1.3.1(B1.3.1)', 'A1.3.2(B1.3.2)', 'A2.3.1(B2.3.2)', 'A2.3.2(B2.3.2)', 'B3.2.1', 'B3.2.2'], loc='best')

# %% [markdown]
# ###Results:

# %% [markdown]
# Notebooks [B3.2.1](http://nbviewer.ipython.org/github/hushchyn-mikhail/CERN_Time_Series/blob/master/B._Classification/B3.2.1._NewFeatures_52weeks/notebook.ipynb) and [B3.2.2](http://nbviewer.ipython.org/github/hushchyn-mikhail/CERN_Time_Series/blob/master/B._Classification/B3.2.2._NewFeatures_78weeks/notebook.ipynb) give better results.

# %% [markdown]
# #Chapter C

# %% [markdown]
# This chapter contains several versions of the notebook [B3.2.2](http://nbviewer.ipython.org/github/hushchyn-mikhail/CERN_Time_Series/blob/master/B._Classification/B3.2.2._NewFeatures_78weeks/notebook.ipynb). There are several variations of the classifier training methods and the new features.
#
# The chapter was divided into 3 sections: C1, C2, C3.

# %% [markdown]
# ###Section C1

# %% [markdown]
# **C1.1:** Notebook [C1.1](http://nbviewer.ipython.org/github/hushchyn-mikhail/CERN_Time_Series/blob/master/C._NewFeatures/C1.1._NewFeatures_78weeks/notebook.ipynb) is just a copy of the notebook [B3.2.2](http://nbviewer.ipython.org/github/hushchyn-mikhail/CERN_Time_Series/blob/master/B._Classification/B3.2.2._NewFeatures_78weeks/notebook.ipynb)

# %%
#get variables
keeper = ipykee.Keeper("C._NewFeatures")
session = keeper["C1.1._NewFeatures_78weeks"]
vars_c11 = session.get_variables("master")
#variables.keys()
# Out:
# Please, save your notebook before commit!

# %% [markdown]
# **C1.2-C1.5:** Notebooks [C1.2-C1.5](http://nbviewer.ipython.org/github/hushchyn-mikhail/CERN_Time_Series/tree/master/C._NewFeatures/) are evolution of the notebook C1.1. All data was divided into several groups: Monte Carlo, Real Data. Each of these groups were divided into additional groups by Configuration and Stripping. Each of these groups has its own classifier for the popularity calculation.
#
# Comparison of these methods with the method in notebook C1.1 shows in the notebooks. Differences of the results if low.

# %% [markdown]
# ###Section C2

# %% [markdown]
# **C2.1:** Notebook [C2.1.1](http://nbviewer.ipython.org/github/hushchyn-mikhail/CERN_Time_Series/blob/master/C._NewFeatures/C2.1.1._RelativeNewFeatures_78weeks/notebook.ipynb) describes the same approach as the notebook C1.1, but all features were recalculated relative the "Creation-week" variable.

# %%
#get variables
keeper = ipykee.Keeper("C._NewFeatures")
session = keeper["C2.1.1._RelativeNewFeatures_78weeks"]
vars_c21 = session.get_variables("master")
#variables.keys()
# Out:
# Please, save your notebook before commit!

# %% [markdown]
# **C2.2-C2.4:** Notebooks [C1.2-C1.5](http://nbviewer.ipython.org/github/hushchyn-mikhail/CERN_Time_Series/tree/master/C._NewFeatures/) are evolution of the notebook C2.1. All data was divided into several groups: Monte Carlo, Real Data. Each of these groups were divided into additional groups by Configuration and Stripping. Each of these groups has its own classifier for the popularity calculation.
#
# Comparison of these methods with the method in notebook C2.1 shows in the notebooks. Differences of the results if low.

# %% [markdown]
# ###Section C3

# %% [markdown]
# **C3.1**: Notebook [C3.1.1](http://nbviewer.ipython.org/github/hushchyn-mikhail/CERN_Time_Series/blob/master/C._NewFeatures/C3.1.1._RelativeNewFeatures_NormedNbOfUsages_78weeks/notebook.ipynb) contains the variabnles from notebook C1.1 and several additional variables for classifier training.

# %%
#get variables
keeper = ipykee.Keeper("C._NewFeatures")
session = keeper["C3.1.1._RelativeNewFeatures_NormedNbOfUsages_78weeks"]
vars_c311 = session.get_variables("master")
#variables.keys()
# Out:
# Please, save your notebook before commit!

# %% [markdown]
# * Notebook [C3.1.2](http://nbviewer.ipython.org/github/hushchyn-mikhail/CERN_Time_Series/blob/master/C._NewFeatures/C3.1.2._NewFeatures_NormedNbOfUsages_78weeks/notebook.ipynb) contains the variabnles from notebook C2.1.1 and several additional variables for classifier training.

# %%
#get variables
keeper = ipykee.Keeper("C._NewFeatures")
session = keeper["C3.1.2._NewFeatures_NormedNbOfUsages_78weeks"]
vars_c312 = session.get_variables("master")
#variables.keys()
# Out:
# Please, save your notebook before commit!

# %% [markdown]
# **Comparison of the models in chapter C**

# %%
#ROC - curve
figure(figsize=(15, 5))
subplot(121)
vars_c11['report.roc()'].plot()
vars_c21['report.roc()'].plot()
vars_c311['report.roc()'].plot()
vars_c312['report.roc()'].plot()
legend(['C1.1(B3.2.2)', 'C2.1.1', 'C3.1.1', 'C3.1.2'], loc='best')
subplot(122)
vars_c11['report2.roc()'].plot()
vars_c21['report2.roc()'].plot()
vars_c311['report2.roc()'].plot()
vars_c312['report2.roc()'].plot()
legend(['C1.1(B3.2.2)', 'C2.1.1', 'C3.1.1', 'C3.1.2'], loc='best')

# %% [markdown]
# ###Results:

# %% [markdown]
# There are no differences in results of the notebooks. But som methods may be more preferable.

# %%
import ipykee
#ipykee.create_project("Overview", repository="git@github.com:hushchyn-mikhail/CERN_Time_Series.git")
session = ipykee.Session(project_name="Overview")
# Out:
# This notebook has name Overview
# Please, save your notebook before commit!

# %%
session.commit("First commit")
# Out:
# Created directory for notebook: Overview
# Copied last saved state of notebook and dumped kernel history
# Successfuly commited
# 6b027c76599e714dcc1c6048925d56f405ade987 Overview: First commit
